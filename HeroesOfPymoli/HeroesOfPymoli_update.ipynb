# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_df = pd.read_csv(file_to_load)
purchase_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
# Total number of Players and display series
player_ct = len(purchase_df["SN"].value_counts())
player_ct = pd.Series(player_ct).reset_index()
player_ct.columns = ['', 'Total Players']
player_ct
# Out:
#       Total Players
# 0  0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Find the total of Unique Items bought.
uniq_items_tots = len(purchase_df["Item Name"].unique())

# Find the Average Price of purchases.
avg_price = purchase_df["Price"].mean()

# Find the Total Revenue of purchases.
revenue_total = purchase_df["Price"].sum()

# Find the Total Number of Purchases
total_purchases = purchase_df["Item ID"].count()

# Make summary df of purchase analysis findings
total_puranalysis_df = pd.DataFrame({"Number of Unique Items": [uniq_items_tots], 
                              "Average Price": avg_price, 
                              "Number of Purchases": total_purchases,
                              "Total Revenue": revenue_total})
total_puranalysis_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# Total count of players by gender
# gender_count = pd.DataFrame(gender_count)

# Make variables for each gender and add for total players.
male_ct = 652
female_ct = 113
onon_ct = 15
total_count = male_ct + female_ct + onon_ct

# Add column for percentage of each group and calculate it based off of variables above.
gender_count['Percentage of Players']= gender_count['Gender']*100/total_count
gender_count
# Out:
#                        Gender  Percentage of Players
# Male                      652                    NaN
# Female                    113                    NaN
# Other / Non-Disclosed      15                    NaN

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Groupby gender
gender_group = purchase_df.groupby(['Gender'])

# Calculate purchase count
g_purch_count = gender_group["Item ID"].count()

# Calculate average purchase price
g_avg_price = gender_group["Price"].mean()

# Calculate average purchase total per person
total_purch = gender_group['Price'].sum()

# Make dataframe summary of purchases by gender
gender_puranalysis_df = pd.DataFrame({"Purchase Count": g_purch_count, 
                              "Average Purchase Price": g_avg_price, 
                              "Average Purchase Total per Person": total_purch})
gender_puranalysis_df
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Average Purchase Total per Person
# Gender
# Female                                            361.94
# Male                                             1967.64
# Other / Non-Disclosed                              50.19

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Make dataframe for age and rename columns
age_df = purchase_df["Age"].value_counts()
age_df = pd.DataFrame(age_df).reset_index()
age_rename = age_df.rename(columns={'index': 'Age', 'Age': 'Total Count'})

# Add a variable for total players
total_plyrs = 576

# Add column for percentage of players in age and calculate it.
age_rename['Percentage of Players']= age_rename['Total Count']*100/total_plyrs

# Make a bin and label for age
age_bins = [0, 10, 14, 19, 24, 29, 34, 39, 45]
age_rng_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# Slice data to place it into bins
pd.cut(age_rename["Age"], age_bins, labels=age_rng_labels)
age_rename['Age Range'] = pd.cut(age_rename["Age"], age_bins, labels=age_rng_labels)

# Groupby Age Range. Get total of players by count and percentage in each age group.
age_rename = age_rename.groupby('Age Range')
age_rename[['Age Range', 'Total Count', 'Percentage of Players']].sum()
# Out:
#            Total Count  Percentage of Players
# Age Range
# <10                 32               5.555556
# 10-14               19               3.298611
# 15-19              136              23.611111
# 20-24              365              63.368056
# 25-29              101              17.534722
# 30-34               73              12.673611
# 35-39               41               7.118056
# 40+                 13               2.256944

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
age_group = purchase_df.groupby(['Age'])
# Calculate purchase count
age_purch_count = age_group["Item ID"].count()

# Calculate average purchase price
age_avg_price = age_group["Price"].mean()

# Calculate average purchase total per person
age_total_purch = age_group['Price'].sum()

# Make dataframe summary of purchases by gender
age_puranalysis_df = pd.DataFrame({"Purchase Count": age_purch_count, 
                              "Average Purchase Price": age_avg_price, 
                              "Average Purchase Total per Person": age_total_purch})

#reset index in order to get age range?
age_puranalysis_df.reset_index()

# # Make a bin and label for age
# age_bins = [0, 10, 14, 19, 24, 29, 34, 39, 45]
# age_rng_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# pd.cut(age_group['Age'], age_bins, labels=age_rng_labels)
# Out:
#     Age  Purchase Count  Average Purchase Price  \
# 0     7               9                3.654444
# 1     8               8                3.246250
# 2     9               6                3.045000
# 3    10               9                3.536667
# 4    11               7                2.684286
# 5    12               6                2.633333
# 6    13               4                2.362500
# 7    14               2                3.455000
# 8    15              35                3.018571
# 9    16              30                3.018667
# 10   17              22                2.930909
# 11   18              26                3.162308
# 12   19              23                3.042609
# 13   20              99                3.174949
# 14   21              62                2.915161
# 15   22              70                2.955000
# 16   23              67                3.013881
# 17   24              67                3.137612
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
top_spenders = purchase_df.groupby(["SN", "Purchase ID"])
top_spenders.counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-9c6057fb89ee> in <module>
#       1 top_spenders = purchase_df.groupby(["SN", "Purchase ID"])
# ----> 2 top_spenders.counts()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'counts'

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Retrieve the Item ID, Item Name, and Item Price columns
popular_items_df = purchase_df[["Item ID", "Item Name", "Price"]]

# Grouby Item ID and Item Name
popular_items_df["Item ID", "Item Name"].groupby()
# popular_items_df["Item Name"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Item ID', 'Item Name')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-b155483718da> in <module>
#       3
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 92      Final Critic                                              8
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 92      Final Critic                                      $4.88
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
